# %% [markdown]
# **CSE4022 NATURAL LANGUAGE PROCESSING**
#
# **DIGITAL ASSIGNMENT 2**
#
# **Name - Siddhartha Mishra**
#
# **Regno - 19BCE1104**

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %% [markdown]
# **Loading the corpora -**

# %%
with open('Siddyyboyy.txt') as f:
  corpora = f.read()

# %%
print(corpora)
# Out:
# Hi This is Siddhartha. I am currently in the final year of my B. Tech in Computer Science and Engineering. Within the duration of my B. Tech, I realised that I want to continue my studies hence I decided to pursue a masters degree in Embedded Systems. Throughout my engineering journey, I was looking for my true calling and in my 6th semester, I realised it to be Embedded Systems which is the meeting point of cutting edge hardware and software. I have chosen Europe and the UK as my preferred locations to apply for colleges. Although my personal preference is Netherlands as it is very advanced in Embedded Systems. I will be applying to colleges like TU Delft, TU Eindhoven, University of Twente, KTH Royal University, Uppsala University, University of Southampton, Saarland University, etc. Out of all of these, my personal preference is TU Eindhoven because the research work they have done there on Embedded Systems is very impressive. My elder brother ignited my interest in Embedded Syste
# ...

# %% [markdown]
# **Word Segmentation of the corpus -**

# %%
list_word=nltk.word_tokenize(corpora)
list_word
# Out:
# ['Hi',
#  'This',
#  'is',
#  'Siddhartha',
#  '.',
#  'I',
#  'am',
#  'currently',
#  'in',
#  'the',
#  'final',
#  'year',
#  'of',
#  'my',
#  'B',
#  '.',
#  'Tech',
#  'in',
#  'Computer',
#  'Science',
#  'and',
#  'Engineering',
#  '.',
#  'Within',
#  'the',
#  'duration',
#  'of',
#  'my',
#  'B',
#  '.',
#  'Tech',
#  ',',
#  'I',
#  'realised',
#  'that',
#  'I',
#  'want',
#  'to',
#  'continue',
#  'my',
#  'studies',
#  'hence',
#  'I',
#  'decided',
#  'to',
#  'pursue',
#  'a',
#  'masters',
#  'degree',
#  'in',
#  'Embedded',
#  'Systems',
#  '.',
#  'Throughout',
#  'my',
#  'engineering',
#  'journey',
#  ',',
#  'I',
#  'was',
#  'looking',
#  'for',
#  'my',
#  'true',
#  'calling',
#  'and',
#  'in',
#  'my',
#  '6th',
#  'semester',
#  ',',
#  'I',
#  'realised',
#  'it',
#  'to',
#  'be',
#  'Embedded',
#  'Systems',
#  'which',
#  'is',
#  'the',
#  'meeting',
#  'point',
#  'of',
#  'cutting',
#  'edge',
#  'hardware',
#  'and',
#  'software',
#  '.',
# ...

# %% [markdown]
# **Sentence segmentation of the corpus -**

# %%
list_sent=nltk.sent_tokenize(corpora)
list_sent
# Out:
# ['Hi This is Siddhartha.',
#  'I am currently in the final year of my B.',
#  'Tech in Computer Science and Engineering.',
#  'Within the duration of my B.',
#  'Tech, I realised that I want to continue my studies hence I decided to pursue a masters degree in Embedded Systems.',
#  'Throughout my engineering journey, I was looking for my true calling and in my 6th semester, I realised it to be Embedded Systems which is the meeting point of cutting edge hardware and software.',
#  'I have chosen Europe and the UK as my preferred locations to apply for colleges.',
#  'Although my personal preference is Netherlands as it is very advanced in Embedded Systems.',
#  'I will be applying to colleges like TU Delft, TU Eindhoven, University of Twente, KTH Royal University, Uppsala University, University of Southampton, Saarland University, etc.',
# ...

# %% [markdown]
# **Converting to the lower case -**

# %%
lowercase_words=[]
for sent in list_sent:
  for word in sent.split():
    lowercase_words.append(word.lower())

lowercase_words
# Out:
# ['hi',
#  'this',
#  'is',
#  'siddhartha.',
#  'i',
#  'am',
#  'currently',
#  'in',
#  'the',
#  'final',
#  'year',
#  'of',
#  'my',
#  'b.',
#  'tech',
#  'in',
#  'computer',
#  'science',
#  'and',
#  'engineering.',
#  'within',
#  'the',
#  'duration',
#  'of',
#  'my',
#  'b.',
#  'tech,',
#  'i',
#  'realised',
#  'that',
#  'i',
#  'want',
#  'to',
#  'continue',
#  'my',
#  'studies',
#  'hence',
#  'i',
#  'decided',
#  'to',
#  'pursue',
#  'a',
#  'masters',
#  'degree',
#  'in',
#  'embedded',
#  'systems.',
#  'throughout',
#  'my',
#  'engineering',
#  'journey,',
#  'i',
#  'was',
#  'looking',
#  'for',
#  'my',
#  'true',
#  'calling',
#  'and',
#  'in',
#  'my',
#  '6th',
#  'semester,',
#  'i',
#  'realised',
#  'it',
#  'to',
#  'be',
#  'embedded',
#  'systems',
#  'which',
#  'is',
#  'the',
#  'meeting',
#  'point',
#  'of',
#  'cutting',
#  'edge',
#  'hardware',
#  'and',
#  'software.',
#  'i',
#  'have',
#  'chosen',
#  'europe',
#  'and',
#  'the',
# ...

# %% [markdown]
# **The number of words in the corpus -**

# %%
len(lowercase_words)
# Out:
# 209

# %% [markdown]
# **Removal of the Stop-words from the corpus -**

# %%
stop_words = set(stopwords.words('english'))
filtered_words=[]
for word in lowercase_words:
  if word not in stop_words:
    filtered_words.append(word)

filtered_words
# Out:
# ['hi',
#  'siddhartha.',
#  'currently',
#  'final',
#  'year',
#  'b.',
#  'tech',
#  'computer',
#  'science',
#  'engineering.',
#  'within',
#  'duration',
#  'b.',
#  'tech,',
#  'realised',
#  'want',
#  'continue',
#  'studies',
#  'hence',
#  'decided',
#  'pursue',
#  'masters',
#  'degree',
#  'embedded',
#  'systems.',
#  'throughout',
#  'engineering',
#  'journey,',
#  'looking',
#  'true',
#  'calling',
#  '6th',
#  'semester,',
#  'realised',
#  'embedded',
#  'systems',
#  'meeting',
#  'point',
#  'cutting',
#  'edge',
#  'hardware',
#  'software.',
#  'chosen',
#  'europe',
#  'uk',
#  'preferred',
#  'locations',
#  'apply',
#  'colleges.',
#  'although',
#  'personal',
#  'preference',
#  'netherlands',
#  'advanced',
#  'embedded',
#  'systems.',
#  'applying',
#  'colleges',
#  'like',
#  'tu',
#  'delft,',
#  'tu',
#  'eindhoven,',
#  'university',
#  'twente,',
#  'kth',
#  'royal',
#  'university,',
#  'uppsala',
#  'university,',
#  'university',
# ...

# %% [markdown]
# **Count of words after Stop-words removal -**

# %%
len(filtered_words)
# Out:
# 111

# %% [markdown]
# **Stemming of the filtered list of words -**

# %%
ps = PorterStemmer()
for w in filtered_words:
  print(w," : ", ps.stem(w))
# Out:
# hi  :  hi
# siddhartha.  :  siddhartha.
# currently  :  current
# final  :  final
# year  :  year
# b.  :  b.
# tech  :  tech
# computer  :  comput
# science  :  scienc
# engineering.  :  engineering.
# within  :  within
# duration  :  durat
# b.  :  b.
# tech,  :  tech,
# realised  :  realis
# want  :  want
# continue  :  continu
# studies  :  studi
# hence  :  henc
# decided  :  decid
# pursue  :  pursu
# masters  :  master
# degree  :  degre
# embedded  :  embed
# systems.  :  systems.
# throughout  :  throughout
# engineering  :  engin
# journey,  :  journey,
# looking  :  look
# true  :  true
# calling  :  call
# 6th  :  6th
# semester,  :  semester,
# realised  :  realis
# embedded  :  embed
# systems  :  system
# meeting  :  meet
# point  :  point
# cutting  :  cut
# edge  :  edg
# hardware  :  hardwar
# software.  :  software.
# chosen  :  chosen
# europe  :  europ
# uk  :  uk
# preferred  :  prefer
# locations  :  locat
# apply  :  appli
# colleges.  :  colleges.
# ...

# %% [markdown]
# **Lemmatization of the filtered words -**

# %%
lemmatizer = WordNetLemmatizer()
for w in filtered_words:
  print(w," : ", lemmatizer.lemmatize(w))
# Out:
# hi  :  hi
# siddhartha.  :  siddhartha.
# currently  :  currently
# final  :  final
# year  :  year
# b.  :  b.
# tech  :  tech
# computer  :  computer
# science  :  science
# engineering.  :  engineering.
# within  :  within
# duration  :  duration
# b.  :  b.
# tech,  :  tech,
# realised  :  realised
# want  :  want
# continue  :  continue
# studies  :  study
# hence  :  hence
# decided  :  decided
# pursue  :  pursue
# masters  :  master
# degree  :  degree
# embedded  :  embedded
# systems.  :  systems.
# throughout  :  throughout
# engineering  :  engineering
# journey,  :  journey,
# looking  :  looking
# true  :  true
# calling  :  calling
# 6th  :  6th
# semester,  :  semester,
# realised  :  realised
# embedded  :  embedded
# systems  :  system
# meeting  :  meeting
# point  :  point
# cutting  :  cutting
# edge  :  edge
# hardware  :  hardware
# software.  :  software.
# chosen  :  chosen
# europe  :  europe
# uk  :  uk
# preferred  :  preferred
# locations  :  location
# ...

# %% [markdown]
# **Part of speech tagging of the filtered-words -**

# %%
nltk.pos_tag(filtered_words)
# Out:
# [('hi', 'NN'),
#  ('siddhartha.', 'NN'),
#  ('currently', 'RB'),
#  ('final', 'JJ'),
#  ('year', 'NN'),
#  ('b.', 'NN'),
#  ('tech', 'NN'),
#  ('computer', 'NN'),
#  ('science', 'NN'),
#  ('engineering.', 'NN'),
#  ('within', 'IN'),
#  ('duration', 'NN'),
#  ('b.', 'NN'),
#  ('tech,', 'NNS'),
#  ('realised', 'VBD'),
#  ('want', 'JJ'),
#  ('continue', 'NN'),
#  ('studies', 'NNS'),
#  ('hence', 'RB'),
#  ('decided', 'VBD'),
#  ('pursue', 'NN'),
#  ('masters', 'NNS'),
#  ('degree', 'VBP'),
#  ('embedded', 'VBN'),
#  ('systems.', 'NN'),
#  ('throughout', 'IN'),
#  ('engineering', 'NN'),
#  ('journey,', 'NN'),
#  ('looking', 'VBG'),
#  ('true', 'JJ'),
#  ('calling', 'VBG'),
#  ('6th', 'CD'),
#  ('semester,', 'NNS'),
#  ('realised', 'VBD'),
#  ('embedded', 'JJ'),
#  ('systems', 'NNS'),
#  ('meeting', 'VBG'),
#  ('point', 'NN'),
#  ('cutting', 'NN'),
#  ('edge', 'NN'),
#  ('hardware', 'NN'),
#  ('software.', 'JJ'),
#  ('chosen', 'VBN'),
#  ('europe', 'NN'),
#  ('uk', 'NN'),
# ...

# %% [markdown]
# **Part of Speech tagging for the list of all the words -**

# %%
nltk.pos_tag(list_word)
# Out:
# [('Hi', 'NNP'),
#  ('This', 'DT'),
#  ('is', 'VBZ'),
#  ('Siddhartha', 'NNP'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('am', 'VBP'),
#  ('currently', 'RB'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('final', 'JJ'),
#  ('year', 'NN'),
#  ('of', 'IN'),
#  ('my', 'PRP$'),
#  ('B', 'NNP'),
#  ('.', '.'),
#  ('Tech', 'NN'),
#  ('in', 'IN'),
#  ('Computer', 'NNP'),
#  ('Science', 'NNP'),
#  ('and', 'CC'),
#  ('Engineering', 'NNP'),
#  ('.', '.'),
#  ('Within', 'IN'),
#  ('the', 'DT'),
#  ('duration', 'NN'),
#  ('of', 'IN'),
#  ('my', 'PRP$'),
#  ('B', 'NNP'),
#  ('.', '.'),
#  ('Tech', 'NNP'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('realised', 'VBD'),
#  ('that', 'IN'),
#  ('I', 'PRP'),
#  ('want', 'VBP'),
#  ('to', 'TO'),
#  ('continue', 'VB'),
#  ('my', 'PRP$'),
#  ('studies', 'NNS'),
#  ('hence', 'VBP'),
#  ('I', 'PRP'),
#  ('decided', 'VBD'),
#  ('to', 'TO'),
#  ('pursue', 'VB'),
#  ('a', 'DT'),
#  ('masters', 'NNS'),
#  ('degree', 'VBP'),
#  ('in', 'IN'),
#  ('Embedded', 'NNP'),
# ...
